# %% [markdown]
# ## 2024-06-18

# %%
from bs4 import BeautifulSoup

html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a>
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>
</body></html>
"""

# %%
# Task6_0618. 주어진 HTML 문서에서 모든 $<a>$ 태그를 추출하세요.
soup = BeautifulSoup(html_doc, 'html.parser')
a_tags = soup.find_all('a')
for tag in a_tags:
    print(tag)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
# Task7_0618. 주어진 HTML 문서에서 첫 번째 $<p>$ 태그의 텍스트를 추출하세요.
p_tags = soup.find('p')
print(p_tags.get_text())
# Out:
# The Dormouse's story

# %%
# Task8_0618. 주어진 HTML 문서에서 모든 링크의 URL을 추출하세요.
for tag in a_tags:
    print(tag['href'])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
# Task9_0618. 주어진 HTML 문서에서 클래스가 sister인 모든 태그를 추출하세요.
sister_tags = soup.find_all(class_='sister')
for tag in sister_tags:
    print(tag)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
# Task10_0618. 주어진 HTML 문서에서 ID가 link1인 태그를 추출하세요 
link1_tag = soup.find(id='link1')
print(link1_tag)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
# Task11_0618. 주어진 HTML 문서에서 모든 텍스트를 추출하세요.
text = soup.get_text()
print(text)
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Elsie
# Lacie
# Tillie

# %%
# Task12_0618. 주어진 HTML 문서에서 href 속성이 http://example.com/lacie인 태그를 추출하세요.
lacie_tag = soup.find(href="http://example.com/lacie")
print(lacie_tag)
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
# Task13_0618. 주어진 HTML 문서에서 ID가 link1인 태그의 부모 태그를 추출하세요.
link1_tag = soup.find(id='link1')
parent_tag = link1_tag.find_parent()

print(parent_tag)
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# </body>

# %%
# Task14_0618. 주어진 HTML 문서에서 ID가 link1인 태그의 다음 형제 태그를 추출하세요.
print(link1_tag.find_next_sibling())
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
# Task15_0618. 주어진 HTML 문서에서 ID가 link1인 태그의 href 속성 값을 추출하세요.
print(link1_tag['href'])
# Out:
# http://example.com/elsie

# %% [markdown]
# ## 2024-06-19

# %%
from bs4 import BeautifulSoup

html_content = '<html><body><h1>Title</h1><p class="content">First paragraph.</p><p class="content">Second paragraph.</p></body></html>'
soup = BeautifulSoup(html_content,'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <h1>
#    Title
#   </h1>
#   <p class="content">
#    First paragraph.
#   </p>
#   <p class="content">
#    Second paragraph.
#   </p>
#  </body>
# </html>

# %%
# Task1_0619. 다음 사항을 수행하세요.
# - 첫 번째로 매칭되는 'p' 태그 찾기
# - 모든 'p' 태그 찾기
# - 클래스가 'content'인 첫 번째 'p' 태그 찾기
# - 클래스가 'content'인 모든 'p' 태그 찾기
# - 특정 'p' 태그의 모든 부모 태그 찾기
# - 특정 'p' 태그의 첫 번째 부모 태그 찾기
# - 특정 'p' 태그의 다음 형제 태그 찾기
# - 특정 'p' 태그의 이전 형제 태그 찾기
# - 특정 'p' 태그 다음에 위치한 모든 태그나 문자열 찾기
# - 특정 'p' 태그 이전에 위치한 모든 태그나 문자열 찾기 

# BeautifulSoup 객체 생성
soup = BeautifulSoup(html_content, 'html.parser')

# 첫 번째로 매칭되는 'p' 태그 찾기
first_p = soup.find('p')
print("첫 번째 'p' 태그:", first_p)

# 모든 'p' 태그 찾기
all_p = soup.find_all('p')
print("모든 'p' 태그:", all_p)

# 클래스가 'content'인 첫 번째 'p' 태그 찾기
first_content_p = soup.find('p', class_='content')
print("클래스가 'content'인 첫 번째 'p' 태그:", first_content_p)

# 클래스가 'content'인 모든 'p' 태그 찾기
all_content_p = soup.find_all('p', class_='content')
print("클래스가 'content'인 모든 'p' 태그:", all_content_p)

# 특정 'p' 태그의 모든 부모 태그 찾기
specific_p = soup.find('p', class_='content')
all_parents = specific_p.find_parents()
print("특정 'p' 태그의 모든 부모 태그:", all_parents)

# 특정 'p' 태그의 첫 번째 부모 태그 찾기
first_parent = specific_p.find_parent()
print("특정 'p' 태그의 첫 번째 부모 태그:", first_parent)

# 특정 'p' 태그의 다음 형제 태그 찾기
next_sibling = specific_p.find_next_sibling()
print("특정 'p' 태그의 다음 형제 태그:", next_sibling)

# 특정 'p' 태그의 이전 형제 태그 찾기
previous_sibling = specific_p.find_previous_sibling()
print("특정 'p' 태그의 이전 형제 태그:", previous_sibling)

# 특정 'p' 태그 다음에 위치한 모든 태그나 문자열 찾기
next_elements = specific_p.find_all_next()
print("특정 'p' 태그 다음에 위치한 모든 태그나 문자열:", next_elements)

# 특정 'p' 태그 이전에 위치한 모든 태그나 문자열 찾기
previous_elements = specific_p.find_all_previous()
print("특정 'p' 태그 이전에 위치한 모든 태그나 문자열:", previous_elements)
# Out:
# 첫 번째 'p' 태그: <p class="content">First paragraph.</p>
# 모든 'p' 태그: [<p class="content">First paragraph.</p>, <p class="content">Second paragraph.</p>]
# 클래스가 'content'인 첫 번째 'p' 태그: <p class="content">First paragraph.</p>
# 클래스가 'content'인 모든 'p' 태그: [<p class="content">First paragraph.</p>, <p class="content">Second paragraph.</p>]
# 특정 'p' 태그의 모든 부모 태그: [<body><h1>Title</h1><p class="content">First paragraph.</p><p class="content">Second paragraph.</p></body>, <html><body><h1>Title</h1><p class="content">First paragraph.</p><p class="content">Second paragraph.</p></body></html>, <html><body><h1>Title</h1><p class="content">First paragraph.</p><p class="content">Second paragraph.</p></body></html>]
# 특정 'p' 태그의 첫 번째 부모 태그: <body><h1>Title</h1><p class="content">First paragraph.</p><p class="content">Second paragraph.</p></body>
# 특정 'p' 태그의 다음 형제 태그: <p class="content">Second paragraph.</p>
# 특정 'p' 태그의 이전 형제 태그: <h1>Title</h1>
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 예시 뉴스 페이지 URL
url = 'http://news.naver.com'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url,headers=headers)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\n<!doctype html>\n<html lang="ko">\n\t<head>\n\t\t<title id="browserTitleArea">네이버 뉴스</title>\n\t\t\n\n\n<script>\n\tfunction isMobileDevice() {\n\t\treturn /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);\n\t}\n</script>\n<script>\n\t(function () {\n\t\ttry {\n\t\t\tif (isMobileDevice() && isAbleApplyPrefersColorScheme()) {\n\t\t\t\t\n\t\t\t\tdocument.querySelector("html").classList.add("DARK_THEME");\n\t\t\t}\n\t\t} catch(e) {}\n\n\t\tfunction isAbleApplyPrefersColorScheme() {\n\t\t\t\n\t\t\tif (window.matchMedia("(prefers-color-scheme)").matches === false) {\n\t\t\t\treturn false;\n\t\t\t}\n\n\t\t\tvar userAgent = navigator.userAgent;\n\n\t\t\tif (userAgent.indexOf("NAVER") > -1) {\n\t\t\t\t\n\t\t\t\tif (/.*NAVER\\([a-zA-Z]*;\\s[a-zA-Z]*;\\s([0-9]*);/.test(userAgent)) {\n\t\t\t\t\treturn Number(RegExp.$1) >= 1000;\n\t\t\t\t}\n\t\t\t} else {\n\t\t\t\t\n\t\t\t\treturn document.cookie.indexOf("NSCS=1") > -1;\n\t\t\t}\n\n\t\t\treturn false;\n\t\t}\n\t})();\n</script>\n\n
# ...

# %%
soup = BeautifulSoup(response.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
# ...

# %%
# Task2_0619. ID를 이용해서 '네이버 뉴스' 추출하세요.
title_element = soup.find('title',id='browserTitleArea')
print(title_element)
title_element.get_text()
# Out:
# <title id="browserTitleArea">네이버 뉴스</title>
# '네이버 뉴스'

# %%
# Task3_0619. soup.find_all(class_='Nitem_link_menu') 대신에 select를 이용하여 동일한 결과를 출력하세요.
cats = soup.select('.Nitem_link_menu')
for idx,cat in enumerate(cats):
    print(f"{idx + 1} {cat.get_text().strip()}")
# Out:
# 1 언론사별
# 2 정치
# 3 경제
# 4 사회
# 5 생활/문화
# 6 IT/과학
# 7 세계
# 8 랭킹
# 9 신문보기
# 10 오피니언
# 11 TV
# 12 팩트체크
# 13 알고리즘 안내
# 14 정정보도 모음

# %%
# Task4_0619. select_one을 이용해서 'https://news.naver.com'에서 "뉴스"를 출력하세요
news_link = soup.select_one('span.Nicon_service')
news_link.text
# Out:
# '뉴스'

# %%
# Task5_0619.'https://news.naver.com'에서 아래 예시와 같이 뉴스 기사 제목을 모두 출력하세요. 
# 예시: 1: [속보] '훈련병 사망' 얼차려 지시 중대장·부중대장 피의자 신분 첫 소환조사
titles = soup.select('.cjs_t')
for idx, title in enumerate(titles):
    print(f"{idx + 1} : {title.get_text().strip()}")
# Out:
# 1 : 영국 기차역 AI 카메라, 승객 '감정 정보' 수집…배고픔까지 파악
# 2 : "외로울 틈이 없어요" 입주민들과 여행 가고 동아리 활동까지…'위스테이별내' 풍경[르포]
# 3 : 정신질환으로 우발적 살인? '심신미약'이면 여성 살해해도 되나
# 4 : 양육비 안 준 부모 164명, 출국금지·명단공개 등 제재
# 5 : “귀엽지만 음식에 털 날려서…” 반려동물 식당 출입에 곳곳 갈등
# 6 : 정용진 신세계 '신상필벌' 인사에 직원들 ‘긴장’
# 7 : BBQ, '4000원 할인 쿠폰' 프로모션...민심 잡기 나선다
# 8 : “한달에 3천만원 저축, 연봉 5~6억”…악착같이 모은다는 무명개그맨의 정체
# 9 : [이충재의 인사이트] 나경원, 왜 '빠루 사건'을 소환했나
# 10 : 1주기 앞두고 오송참사 현장 찾은 유족들 '짙은 안타까움'...재개통 우려도
# 11 : "자식 돈에 어디 숟가락 얹나"…박세리 논란에 손흥민父 재조명
# 12 : "음주운전하면 무조건 튀어라"…'음주 혐의' 빠진 김호중에 뿔난 여론
# 13 : '韓, 노동권 꼴찌' 지적하자 11년째 "못 믿는다"는 노동부[오목조목]
# 14 : 美 엔비디아 훈풍에 삼전·SK하닉 주가 고공행진 언제까지
# 15 : “푸틴 태우고 운전” 김정은 포착…선물받은 ‘아우루스’ 직접 몰았다
# 16 : [단독] 영화숙·재생원 악몽, 국제사회에 첫 증언
# 17 : "벌써 설렌다"…내년 '추석 연휴' 최대 열흘
# 18 : 어제 ‘인구국가비상사태’ 보셨나요…‘진짜 비상사태’ 3가지 빠졌던데
# 19 : 백종원·곽튜브 제쳤다… 한국인이 좋아하는 유튜버 1위는?
# 20 : "한쪽 침략당하면 상호지원"…랍스터 먹고, 한밤 배웅까지
# 21 : 오물 풍선 소동, 끝난 게 아니다
# 22 : 내년 추석은 7일 쉰다…주5일 직장인 휴일 '119일'
# 23 : SK하이닉스·삼성전자, HBM부터 낸드까지 '하이브리드 본딩' 도입 잰걸음
# 24 : 끝모를 쌀값 하락…“재고 15만t 신속 격리를”
# ...

# %% [markdown]
# # 2024-06-20

# %%
import requests
from bs4 import BeautifulSoup

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}


url = 'https://serieson.naver.com/v3/movie/ranking/realtime'
response = requests.get(url,headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")

soup.find("span", class_="Title_title__s9o0D").text
# Out:
# '인사이드 아웃(패키지상품 : 더빙판 + 부가영상 추가증정)'

# %%
# Task1_0620. 네이버 영화 순위 사이트에서 영화제목, 가격, 타입(구매 or 대여) 
# 정보를 가져와서 TITLE, PRICE, TYPE 3개의 컬럼과 100개의 데이터포인트로 구성된 데이터프레임을 출력하세요.
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# URL 설정
url = 'https://serieson.naver.com/v3/movie/ranking/realtime'

# HTTP GET 요청
response = requests.get(url)
response.raise_for_status()  # 요청이 성공했는지 확인

# BeautifulSoup을 사용하여 HTML 파싱
soup = BeautifulSoup(response.content, 'html.parser')

# 영화 제목과 가격을 저장할 리스트
titles = []
prices = []
types = []

# 영화 제목과 가격 추출
movies = soup.select('.RankingList_ranking_list__N4QsH > li')

for movie in movies:
    title_tag = movie.select_one('.Title_title__s9o0D')
    if title_tag:
        title = title_tag.get_text(strip=True)
    
        # 가격 및 타입 추출
        price_items = movie.select('.Price_price_item__tOOqb')
        for price_item in price_items:
            type_tag = price_item.select_one('.Price_text__pRk_f')
            price_tag = price_item.select_one('.Price_price__GqXqo')
            if type_tag and price_tag:
                type_text = type_tag.get_text(strip=True)
                price = price_tag.get_text(strip=True)
                
                # 가격에서 "캐시" 및 SVG 태그 제거
                price = re.sub(r'캐시.*', '', price).strip()
                
                titles.append(title)
                prices.append(price)
                types.append(type_text)

# 데이터프레임 생성
df = pd.DataFrame({
    'Title': titles,
    'Price': prices,
    'Type': types
})

# 데이터프레임 출력
df
# Out:
#                                Title   Price Type
# 0   인사이드 아웃(패키지상품 : 더빙판 + 부가영상 추가증정)   7,150   구매
# 1                                콩나물   1,000   구매
# 2                     태극기 휘날리며 - 특별판  10,000   구매
# 3                                설계자  11,000   대여
# 4                          원피스 필름 레드   1,540   대여
# ..                               ...     ...  ...
# 81                               마스크   1,300   대여
# 82                         사운드 오브 뮤직   5,500   구매
# 83                        마지막 한 걸음까지     500   구매
# 84                            흑인 오르페     500   구매
# 85                               수집가   2,500   대여
#
# [86 rows x 3 columns]

# %%
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd


headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

url = 'https://news.daum.net/politics#1'
r = rq.get(url, headers=headers)
html = r.text
soup = BeautifulSoup(html, 'html.parser')

# %%
# Task2_0620. url = 'https://news.daum.net/politics#1'은 정치기사 1페이지인데 10페이지에 있는 기사를 모두 출력하세요. 

import requests
from bs4 import BeautifulSoup
import re

for j in range(1, 11):
    #https://news.daum.net/breakingnews/politics?page=1
    url = f'https://news.daum.net/breakingnews/politics?page={j}'
    print(url)
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    lines = soup.find_all('a',class_="link_txt")
    lines = lines[7:-21]
    for i, tag in enumerate(lines, 1):
        text = tag.get_text().strip().replace(',', '')
        matches = re.findall('[가-힣0-9]+', text)
        print(f"{i}. {' '.join(matches)}")
    print(f'페이지수: {j}')
# Out:
# https://news.daum.net/breakingnews/politics?page=1
# 1. 박찬대 채해병 순직 1주기 전 특검법 통과시킬 것
# 2. 속보 유승민 대표 경선 불출마 무의미한 도전이라 결론
# 3. 우크라 무기 지원은 러 행동에 달려 155 포탄 등 방산 대기 중
# 4. 무의미한 도전 유승민 당대표 불출마 선언
# 5. 원희룡 출마 발표 전날 용산 찾아 대통령 존중한다
# 6. 북러 고강도 군사 밀착에 한미도 면밀 대응 외교장관 긴급 통화
# 7. 정치쇼 김재섭 천하제일 비윤 호소대회 원희룡 모종의 일 있었을 것
# 8. 속보 유승민 대표 경선 불출마 무의미한 도전이라고 결론
# 9. 원희룡 모레 국회서 국민의힘 대표 출마 선언 한동훈과 한 날 출사표
# 10. 유승민 전당대회 불출마 선언 무의미한 도전이라 결론
# 11. 외교부 오늘 러시아대사 초치할 듯 북러 조약 항의
# 12. 박찬대 권익위 명품백 답변 에 어처구니 없는 헛소리
# 13. 북 러 군사 협력 범위 불분명 생각보다 더 장기적 더 위험
# 14. 경기도 무장애 관광지 컨설팅 사업 참여 관광지 모집
# 15. 정유라 조민 대법 판결 남았는데 이 타이밍에 결혼을
# 페이지수: 1
# https://news.daum.net/breakingnews/politics?page=2
# 1. 전략사령부 올 하반기 창설 사령관은 육 해 공군 장성 순환보직
# 2. 게시판 식약처 의약품안전관리원 약물안전캠페인
# 3. 원희룡 23일 국회서 당대표 출마 선언 한동훈과 같은날
# 4. 유승민 전당대회 불출마 무의미한 도전
# 5. 윤상현 한동훈 사석서 그 사람 이라고 신뢰 관계 바닥
# 6. 김현기 서울시의장 몽골 울란바토르에 소방차 10대 전달
# 7. 탈북단체 대북전단 30만장 살포
# 8. 북한 6 25 미제 반대 투쟁의 날 앞두고 원수 격멸 의지 굳건
# 9. 현대 폴란드 국제해양 안보포럼 서 잠수함 플랫폼 제안
# ...

# %%
# Task3_0620. 앞에서 출력한 기사 리스트를 pandas 데이터프레임으로 변환 후 csv 파일로 저장 후 다시 불러오세요.

import re
import pandas as pd

soup = BeautifulSoup(html, 'html.parser')

lines = soup.select('body > div > main > section > div.main-sub > div > ul > li > strong > a')
results = []
for i, tag in enumerate(lines, start=1):
    text = tag.get_text().strip().replace(',', '')
    matches = re.findall('[가-힣0-9]+', text)
    result = ' '.join(matches)
    results.append({'Index':i, 'Text':result})
    
df = pd.DataFrame(results)

df.to_csv('news.csv', index=False)
df = pd.read_csv('news.csv')
df
# Out:
#    Index                                     Text
# 0      1         탈북민단체 어젯밤 대북 전단 30만장 살포 북한 대응 주목
# 1      2  이준석 홍준표의 이재명 동탁 비유에 판단 잘못해 일 그르친 원소로 보여
# 2      3            뉴스파이팅 김재원 원희룡 용산 친윤에서 밀어주고 있다
# 3      4      한미동맹엔 없지만 북중동맹에 있는 것 새로운 북러 조약에도 스프
# 4      5       부안 지진 중대본 1단계 10일 만에 해제 시설피해 1196건
# 5      6           영상 추미애 탄핵 6행시 6선 의심스러운 저급함에 민망
# 6      7              부산시의회 24시 부산시민에게 맑은 물 공급하려면
# 7      8             언론은 검찰 애완견 거칠어진 이재명의 속내는 불안감
# 8      9             전쟁상태 지체없이 군사 원조 북러 사실상 동맹 복원
# 9     10   이준석은 양반 이었다 신평 한동훈 이준석보다 과 더 심하게 충돌할 것
